# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_sensor_01.csv')
df
# Out:
#                Timestamp  Temperature (°C)  Humidity (%)  Pressure (kPa)  \
# 0    2025-10-04 19:29:55             27.89         50.58          101.04
# 1    2025-10-04 19:29:56             27.89         50.57          101.04
# 2    2025-10-04 19:29:57             27.89         50.57          101.04
# 3    2025-10-04 19:29:58             27.89         50.58          101.04
# 4    2025-10-04 19:29:59             27.89         50.56          101.04
# ..                   ...               ...           ...             ...
# 436  2025-10-04 19:38:48             28.55         54.74          101.04
# 437  2025-10-04 19:38:49             28.56         54.16          101.04
# 438  2025-10-04 19:38:50             28.57         53.54          101.04
# 439  2025-10-04 19:38:51             28.56         52.97          101.04
# 440  2025-10-04 19:38:52             28.57         52.50          101.04
#
#      Gas Resistance (KOhm)
# 0                   102.82
# 1                   102.44
# 2                   102.69
# 3                   102.69
# 4                   102.57
# ..                     ...
# 436                  93.09
# 437                  94.14
# 438                  94.78
# 439                  94.67
# 440                  94.89
#
# [441 rows x 5 columns]

# %%
#graphs of temperature vs. time, humidity vs. time, pressure vs. time, and gas resistance vs. time
#have no x axis markers
plt.figure(figsize=(10,8))
plt.subplot(2, 2, 1)
plt.plot(df['Timestamp'], df['Temperature (°C)'])
plt.title('Temperature vs Time')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')

plt.subplot(2, 2, 2)
plt.plot(df['Timestamp'], df['Humidity (%)'])
plt.title('Humidity vs Time')
plt.xlabel('Time')
plt.ylabel('Humidity (%)')

plt.subplot(2, 2, 3)
plt.plot(df['Timestamp'], df['Pressure (kPa)'])
plt.title('Pressure vs Time')
plt.xlabel('Time')
plt.ylabel('Pressure (kPa)')

plt.subplot(2, 2, 4)
plt.plot(df['Timestamp'], df['Gas Resistance (KOhm)'])
plt.title('Gas Resistance vs Time')
plt.xlabel('Time')
plt.ylabel('Gas Resistance (KOhm)')

plt.tight_layout()
plt.show()
